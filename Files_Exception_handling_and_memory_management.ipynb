# %%
# What is the difference between interpreted and compiled languages?
'''
Compiled language are translated into machine code once, before execution, resulting in faster runtime. (eg:C, C++)
Interpreted languages are translated line by line during execution by an interpreter. (eg: Python)
'''

# %%
# What is exception handling in Python?
'''
Exception handling in pythoin is a way to handle runtime errors whthout crashing the program.
Uses try, except, else and finally
'''
try:
  x = int("abc")
except ValueError as e:
  print("Invalid Conversion ", e)
# Out:
# Invalid Conversion  invalid literal for int() with base 10: 'abc'

# %%
# What is the purpose of the finally block in exception handling?
'''
The finally is used to exceute code no matter what, wether an exception occurs or not.
Always runs after try/except
'''
try:
    f = open("data.txt", 'w')
except FileNotFoundError:
    print("File not found")
finally:
    f.close()
    print("File Closed")
# Out:
# File Closed

# %%
#  What is logging in Python?
'''
Logging in python is used to record messages about a program's execution for debug, monitoring, and error tracking.
supports levels: DEBUG, INFO, WARNING, ERROR, CRITICAL
'''

# %%
# What is the significance of the __del__ method in Python?
'''
The __del__ method is a destructor in python
Used to release resources (files, database connection)
'''

# %%
# What is the difference between import and from ... import in Python?
'''
import modules
  - imports the entire module
  - Access members using module.name
'''
import math
print(math.sqrt(10))

'''
from ... import name
  - Imports specific members
  - used directly without module prefix
'''
from math import sqrt
print(sqrt(10))
# Out:
# 3.1622776601683795
# 3.1622776601683795

# %%
# How can you handle multiple exceptions in Python?
'''
This can be achived using multiple except or a tuple of exceptions.
'''
try:
    x = int("abc")
except ValueError:
    print("Value error")
except TypeError:
    print("Type error")
print("###")
try:
    x = int("abc")
except (ValueError, TypeError):
    print("Invalid input")
# Out:
# Value error
# ###
# Invalid input

# %%
# What is the purpose of the with statement when handling files in Python?
'''
with statement is used to manage resources safely and automatically opens and closes files.
'''
with open("data.txt", 'r') as f:
  content = f.read()

# %%
# What is the difference between multithreading and multiprocessing?
'''
Multithreading
  - Multiple threads within one process.
  - Shares the same memory.
Multiprocessing
  - Multiple processes.
  - Seperate memory space.
'''

# %%
# What are the advantages of using logging in a program?
'''
Helps in debugging issues.
Tracks program execution flow.
Records erros and warning.
'''

# %%
# What is memory management in Python?
'''
Uses dynamic memory allocation.
Managed by python memory manager.
Uses grabage collection to ramove unused objects.
Reduces memory leaks and manual memory handling.
'''

# %%
# What are the basic steps involved in exception handling in Python
'''
Place risky code inside a try block
Handle errors usinf except
'''

# %%
# Why is memory management important in Python?
'''
Prevents memory leaks
Improves program performance
Automatically frees unused memory
Ensures efficient resource usage
'''

# %%
# What is the role of try and except in exception handling?
'''
try: Contains code that may cause an error
except: Catched and handles the error is it occurs
'''

# %%
# How does Python's garbage collection system work?
'''
It works maiinly in two ways:
Reference counting:
  - Each object keeps a count of reference. When the count becomes zero, memory is freed immediately.
Cyclic grabage collector:
  - Detects and remove circular references
'''

# %%
# What is the purpose of the else block in exception handling?
'''
Execute only if no exception occurs in the try block.
'''

# %%
# What are the common logging levels in Python?
'''
DEBUG: Detailed diagnostic information
INFO: General program information
WARNING: Something unexpected, but program continues
ERROR: Seriour problem, function failed
CRITICAL: Server error, program may stop
'''

# %%
# What is the difference between os.fork() and multiprocessing in Python?
'''
os.fork(): creates a child process by duplicating the parent
multiprocesing: creates processes in portable and say way.
'''

# %%
# What is the importance of closing a file in Python?
'''
It Ensures data is properly written and frees system resources.
best practice to use with.
'''

# %%
# What is the difference between file.read() and file.readline() in Python?
'''
file.read(): Reads the entire file at once
file.readline(): Reads one line at a time.
'''

# %%
# What is the logging module in Python used for
'''
The logging module in python is used to recoed program message for debugging, monitoring, and error tracking.
'''

# %%
# What is the os module in Python used for in file handling?
'''
The os module in python is used for file and directory operations at the system level.
'''

# %%
# What are the challenges associated with memory management in Python?
'''
Circular references can delay memory cleanup.
High memory usage in long-running programs.
Memory leaks due to unused references.
lessa control over manual memory optimization.
'''

# %%
# How do you raise an exception manually in Python?
'''
Using the raise keyword
'''
raise ValueError("Invalid input")

# %%
# Why is it important to use multithreading in certain applications?
'''
Enables concurrent execution.
Better utilization of waiting time.
Reduces overall execution time.
'''

# %%
# How can you open a file for writing in Python and write a string to it?
with open("data.txt", "w") as f:
    f.write("Hello, Python!")

# %%
# Write a Python program to read the contents of a file and print each line.
with open("data.txt", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# Hello, Python!

# %%
# How would you handle a case where the file doesn't exist while trying to open it for reading?
try:
    with open("data.txt", "r") as f:
        print(f.read())
except FileNotFoundError:
    print("File does not exist")
# Out:
# Hello, Python!

# %%
# Write a Python script that reads from one file and writes its content to another file
with open("data.txt", "r") as src, open("destination.txt", "w") as dest:
    dest.write(src.read())

# %%
# How would you catch and handle division by zero error in Python?
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %%
# Write a Python program that logs an error message to a log file when a division by zero exception occurs.

import logging

logging.basicConfig(
    filename="error.log",
    level=logging.ERROR,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

try:
    result = 10 / 0
except ZeroDivisionError:
    logging.error("Division by zero error occurred")
# Out:
# ERROR:root:Division by zero error occurred

# %%
# How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?
import logging

logging.basicConfig(level=logging.INFO)

logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message

# %%
# Write a program to handle a file opening error using exception handling.
try:
    file = open("data.txt", "r")
    print(file.read())
except FileNotFoundError:
    print("Error: File not found")
finally:
    if 'file' in locals():
        file.close()
# Out:
# Hello, Python!

# %%
# How can you read a file line by line and store its content in a list in Python?
lines = []

with open("data.txt", "r") as f:
    for line in f:
        lines.append(line.strip())

# %%
# How can you append data to an existing file in Python?
with open("data.txt", "a") as f:
    f.write("New line added\n")

# %%
# Write a Python program that uses a try-except block to handle an error when attempting to access adictionary key that doesn't exist.
data = {"name": "Alice", "age": 25}

try:
    print(data["salary"])
except KeyError:
    print("Error: Key does not exist")
# Out:
# Error: Key does not exist

# %%
# Write a program that demonstrates using multiple except blocks to handle different types of exceptions.
try:
    x = int("abc")
    y = 10 / 0
except ValueError:
    print("Value error occurred")
except ZeroDivisionError:
    print("Division by zero occurred")
except Exception:
    print("Some other error occurred")
# Out:
# Value error occurred

# %%
#  How would you check if a file exists before attempting to read it in Python?
import os

if os.path.exists("data.txt"):
    with open("data.txt", "r") as f:
        print(f.read())
else:
    print("File does not exist")
# Out:
# Hello, Python!New line added

# %%
# Write a program that uses the logging module to log both informational and error messages.
import logging

logging.basicConfig(
    filename="app.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

logging.info("Program started")

try:
    result = 10 / 0
except ZeroDivisionError:
    logging.error("Division by zero error occurred")

logging.info("Program finished")
# Out:
# ERROR:root:Division by zero error occurred

# %%
# Write a Python program that prints the content of a file and handles the case when the file is empty.
try:
    with open("data.txt", "r") as f:
        content = f.read()
        if content:
            print(content)
        else:
            print("The file is empty")
except FileNotFoundError:
    print("File not found")
# Out:
# Hello, Python!New line added

# %%
# !pip install psutil

# %%
# Demonstrate how to use memory profiling to check the memory usage of a small program.
import psutil
import os

process = psutil.Process(os.getpid())

def memory_mb():
    return process.memory_info().rss / 1024 / 1024

print("Memory before:", memory_mb(), "MB")

# Sample program
a = [i for i in range(1_000_000)]

print("Memory after:", memory_mb(), "MB")
# Out:
# Memory before: 228.0234375 MB
# Memory after: 262.55078125 MB

# %%
# Write a Python program to create and write a list of numbers to a file, one number per line.
numbers = [1, 2, 3, 4, 5]

with open("numbers.txt", "w") as f:
    for num in numbers:
        f.write(str(num) + "\n")

# %%
# How would you implement a basic logging setup that logs to a file with rotation after 1MB?
import logging
from logging.handlers import RotatingFileHandler

logger = logging.getLogger("app_logger")
logger.setLevel(logging.INFO)

handler = RotatingFileHandler(
    "app.log",
    maxBytes=1_000_000,   # 1 MB
    backupCount=3
)

formatter = logging.Formatter(
    "%(asctime)s - %(levelname)s - %(message)s"
)
handler.setFormatter(formatter)

logger.addHandler(handler)

logger.info("Application started")
logger.error("Sample error message")
# Out:
# INFO:app_logger:Application started
# ERROR:app_logger:Sample error message

# %%
# Write a program that handles both IndexError and KeyError using a try-except block.
data = {"a": 1, "b": 2}
numbers = [10, 20, 30]

try:
    print(numbers[5])
    print(data["c"])
except IndexError:
    print("Index out of range")
except KeyError:
    print("Key not found")
# Out:
# Index out of range

# %%
# How would you open a file and read its contents using a context manager in Python?
with open("data.txt", "r") as f:
    content = f.read()
    print(content)
# Out:
# Hello, Python!New line added

# %%
# Write a Python program that reads a file and prints the number of occurrences of a specific word.
word = "python"
count = 0

with open("data.txt", "r") as f:
    for line in f:
        count += line.lower().count(word.lower())

print(f"'{word}' occurred {count} times")
# Out:
# 'python' occurred 1 times

# %%
# How can you check if a file is empty before attempting to read its contents?
import os

if os.path.exists("data.txt") and os.path.getsize("data.txt") > 0:
    with open("data.txt", "r") as f:
        print(f.read())
else:
    print("File is empty or does not exist")
# Out:
# Hello, Python!New line added

# %%
# Write a Python program that writes to a log file when an error occurs during file handling.
import logging

logging.basicConfig(
    filename="file_errors.log",
    level=logging.ERROR,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

try:
    with open("data4.txt", "r") as f:
        print(f.read())
except Exception as e:
    logging.error(f"File handling error: {e}")
# Out:
# ERROR:root:File handling error: [Errno 2] No such file or directory: 'data4.txt'

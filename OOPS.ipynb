# %%
# What is Object-Oriented Programming (OOP)?
'''
OOPs is a programming appraoch where software is built using objects that combine data and methods.
Helps write resuable, maintainable and scalable code.
'''

# %%
# What is a class in OOP?
'''
A class is a blueprint or template used to create objects. Its define the attributes and methods that the object will have.
'''

# %%
# What is an object in OOP?
'''
An object in OOP is an instance of a class. It represent a real-world entity and contains data and behavior defined by the class.
'''

# %%
# What is the difference between abstraction and encapsulation?
'''
Abstraction hides implementation details and shows only essential feature while encapsulation bundles data and methods together and restricts direct access to data.
'''

# %%
# What are dunder methods in Python?
'''
Dunder methods in python are special methods with name starting and ending with double underscores. (__method__)
They define how objects behave with built-in operations.
eg: __init__ -> object initialization
__str__ -> string repersentation
__add__ -> addition behavior
'''

# %%
#  Explain the concept of inheritance in OOP.
'''
Inheritance in OOP is a mechanism where a child class acquire the properties and method of parent class.
It promotes code reuse and establishes a parent-child relationship between classes.
'''

# %%
# What is polymorphism in OOP?
'''
Ploymorphism in OOP means one interface, multiple behaviors.
The same method name can perform different actions depending on the object or class.
'''

# %%
#  How is encapsulation achieved in Python?
'''
Encapsulation in python is achieved by bundling data and methods inside a class and restricting direct access to data using access modifiers.

public-> normal variables
_protected -> single underscore
__provate -> double underscore

'''

# %%
# What is a constructor in Python?
'''
A constructor in pyhton is special method called __init__ that is automatically executed when an object is created. It is used to initialize object data.
'''

# %%
# What are class and static methods in Python?
'''
Class methods use @classmethod and takes cls as the first parameter and they work with class level data only and modify the class state.
Static methods use @staticmethod and do not take self or cls as the first parameter. They behave like normal functions but belong to the class for logical grouping.
'''

# %%
#  What is method overloading in Python?
'''
Method overloading in pyhton means defining multiple methods with the same name but different parameters.
Python does not support traditional method overloading.
It is achived using *args(list)/**kwargs(key-value)
'''

# %%
#  What is method overriding in OOP?
'''
Method overriding in OOP is when a child class provides its own implementation oa a method that is already defined in the parent class.
It allows the child to change or extend behavior of the inherited method.
'''

# %%
#  What is a property decorator in Python?
'''
@property lets you use getter logic without calling a method explicitly.
'''

# %%
# Why is polymorphism important in OOP?
'''
ploymorphism is imp in OOP because it allows the same interface to work with different objects.
'''

# %%
# What is an abstract class in Python
'''
An abstract class in python is a class that cannot be instantiated and is used to define a common interface for its subclass.
'''

# %%
# What are the advantages of OOP?
'''
Resuability -> code can be reused using inheritance
Maintainability -> easier to modify and debug
Scalability -> Suitable for large applications
Encapsulation -> Improves data security
Modularity -> Code is well structed and orginized
'''

# %%
# What is the difference between a class variable and an instance variable?
'''
Class variable: shared by all objects of the class and defined outside methods.
Instance variable: unique to each object and defined using self inside the constructor.
'''

# %%
# What is multiple inheritance in Python?
'''
Multiple inheritance in python is a feature where a child class inherits from more than one parent class.
This allows the child class to access methods and properties of multiple classes.
'''

# %%
# Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python
'''
__str__ -> returns readable used by print()
__repr__ -> returns an developer-focused string repersentation(used in debugging)
'''

# %%
# What is the significance of the ‘super()’ function in Python?
'''
The super() function in python is used to call methods of a parent class from a child class.
'''

# %%
# What is the significance of the __del__ method in Python?
'''
__del__ helps with cleanup when an object is deleted.
'''

# %%
# What is the difference between @staticmethod and @classmethod in Python?
'''
@classmethod works with class where @staticmethod is class-related but independent.
'''

# %%
# How does polymorphism work in Python with inheritance?
'''
polymorphism with inheritance works through method overriding.
The same method call behaves differently depending on the object using it.
'''

# %%
# What is method chaining in Python OOP?
'''
Method chaining improves readability by calling multiple methods sequentially on one object.
eg: obj.method().method().method()
'''

# %%
# What is the purpose of the __call__ method in Python?
'''
The __call__ method in python allows an object to be called like a function.
'''

# %%
# Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!"
class Animal:
  def speak(self):
    print("This animal makes a sound")

class Dog:
  def speak(self):
    print("Bark!")

a = Animal()
a.speak()

d = Dog()
d.speak()
# Out:
# This animal makes a sound
# Bark!

# %%
# Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both

from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

c = Circle(5)
r = Rectangle(4, 6)

print(c.area())
print(r.area())
# Out:
# 78.53981633974483
# 24

# %%
#  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery):
        super().__init__(vehicle_type, brand)
        self.battery = battery

e_car = ElectricCar("Four Wheeler", "tata", "75 kWh")

print(e_car.type)
print(e_car.brand)
print(e_car.battery)
# Out:
# Four Wheeler
# tata
# 75 kWh

# %%
# Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method
class Bird:
    def fly(self):
        print("Bird can fly")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly")

birds = [Sparrow(), Penguin()]

for bird in birds:
    bird.fly()
# Out:
# Sparrow flies high
# Penguin cannot fly

# %%
# Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance")

    def check_balance(self):
        return self.__balance

account = BankAccount(1000)

account.deposit(500)
account.withdraw(300)

print("Balance:", account.check_balance())
# Out:
# Balance: 1200

# %%
#  Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play()
class Instrument:
    def play(self):
        print("Instrument is playing")

class Guitar(Instrument):
    def play(self):
        print("Guitar is playing music")

class Piano(Instrument):
    def play(self):
        print("Piano is playing music")

instruments = [Guitar(), Piano()]

for instrument in instruments:
    instrument.play()
# Out:
# Guitar is playing music
# Piano is playing music

# %%
# Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers
class MathOperations:

    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print(MathOperations.add_numbers(10, 5))       # 15
print(MathOperations.subtract_numbers(10, 5))  # 5
# Out:
# 15
# 5

# %%
# Implement a class Person with a class method to count the total number of persons created
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

p1 = Person("Vatsal")
p2 = Person("Rahul")
p3 = Person("Pooja")

print("Total persons:", Person.total_persons())
# Out:
# Total persons: 3

# %%
# Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

f = Fraction(3, 4)
print(f)
# Out:
# 3/4

# %%
# Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2
print(v3)
# Out:
# (6, 8)

# %%
# Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old")

p = Person("Vatsal", 25)
p.greet()
# Out:
# Hello, my name is Vatsal and I am 25 years old

# %%
#  Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # list of grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades) if self.grades else 0

s = Student("Rahul", [85, 90, 78])
print("Average Grade:", s.average_grade())
# Out:
# Average Grade: 84.33333333333333

# %%
# Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

r = Rectangle()
r.set_dimensions(5, 4)
print("Area:", r.area())
# Out:
# Area: 20

# %%
# Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:
    def calculate_salary(self, hours_worked, hourly_rate):
        return hours_worked * hourly_rate

class Manager(Employee):
    def calculate_salary(self, hours_worked, hourly_rate, bonus):
        base_salary = super().calculate_salary(hours_worked, hourly_rate)
        return base_salary + bonus

e = Employee()
print("Employee Salary:", e.calculate_salary(40, 500))

m = Manager()
print("Manager Salary:", m.calculate_salary(40, 500, 5000))
# Out:
# Employee Salary: 20000
# Manager Salary: 25000

# %%
# Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

p = Product("Laptop", 50000, 2)
print("Total Price:", p.total_price())
# Out:
# Total Price: 100000

# %%
# Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")

animals = [Cow(), Sheep()]

for animal in animals:
    animal.sound()
# Out:
# Moo
# Baa

# %%
# Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year: {self.year_published}"

b = Book("Clean Code", "Robert C. Martin", 2008)
print(b.get_book_info())
# Out:
# Title: Clean Code, Author: Robert C. Martin, Year: 2008

# %%
# Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

m = Mansion("Adajan", 50000000, 12)
print(m.address, m.price, m.number_of_rooms)
# Out:
# Adajan 50000000 12

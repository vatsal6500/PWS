# %%
# What is NumPy, and why is it widely used in Python?
'''
NumPy is a Python library for fast numerical computing.
It is widly used becasue it provides efficient arrays, fast math operations, and is the foundation of data science, machine learning, and scientific computing in Python.
'''

# %%
# How does broadcasting work in NumPy?
'''
Broadcasting lets NumPy perform operations on arrays of different shapes without loops.
'''
import numpy as np

a = np.array([1, 2, 3])
print(a + 10)   # [11 12 13]
# Out:
# [11 12 13]

# %%
# What is a Pandas DataFrame?
'''
A DataFrame is a 2D table-like data structure in Pandas, with rows and columns, similar to an Excel sheet or SQL table.
'''
import pandas as pd

df = pd.DataFrame({
    "Name": ["A", "B"],
    "Age": [20, 25]
})
print(df)
# Out:
#   Name  Age
# 0    A   20
# 1    B   25

# %%
# Explain the use of the groupby() method in Pandas.
'''
In Pandas, groupby() is used to group data by one or more columns and apply operations like sum, mean, or count.
'''
import pandas as pd

df = pd.DataFrame({
    "Dept": ["IT", "IT", "HR"],
    "Salary": [50, 60, 40]
})

df.groupby("Dept")["Salary"].mean()
# Out:
# Dept
# HR    40.0
# IT    55.0
# Name: Salary, dtype: float64

# %%
# Why is Seaborn preferred for statistical visualizations?
'''
Seaborn is preferred for statistical visualizations because it offers built-in statistical plots, clean default styling, and easy integration with Pandas, using less code.
'''

# %%
# What are the differences between NumPy arrays and Python lists?
'''
NumPy arrays are faster and more memory-efficient than Python lists for numerical operations, while lists are more flexible.
'''

# %%
# What is a heatmap, and when should it be used?
'''
A heatmap uses color intensity to represent data values and is used to visualize patterns and correlations in large datasets.
'''

# %%
# What does the term “vectorized operation” mean in NumPy?
'''
In NumPy, a vectorized operation means performing an operation on entire arrays at once, without using explicit loops.
'''

# %%
# How does Matplotlib differ from Plotly?
'''
Matplotlib is used for static plots, while Plotly is used for interactive and web-based visualizations.
'''

# %%
# What is the significance of hierarchical indexing in Pandas?
'''
In Pandas, hierarchical indexing allows a DataFrame or Series to have multiple index levels, enabling representation of higher dimensional data in 2D form.
'''

# %%
# What is the role of Seaborn’s pairplot() function?
'''
In Seaborn, pairplot() is used to visualize pairwise relationships between numerical variables in a dataset.
'''

# %%
# What is the purpose of the describe() function in Pandas?
'''
In Pandas, describe() is used to generate summary statistics of numerical data.
'''

# %%
# Why is handling missing data important in Pandas?
'''
In Pandas, handling missing data is important because missing values can cause incorrect analysis, wrong calculations, and errors in models.
df.dropna()      # remove missing values
df.fillna(0)     # replace missing values
'''

# %%
# What are the benefits of using Plotly for data visualization?
'''
Plotly is used for creating interactive and web-based data visualizations.
'''

# %%
# How does NumPy handle multidimensional arrays?
'''
In NumPy, multidimensional arrays are handled using the ndarray object, which can store data in 1D, 2D, or higher dimensions.
'''

# %%
# What is the role of Bokeh in data visualization?
'''
Bokeh is used to create interactive, web-based visualizations directly in browsers.
'''

# %%
# Explain the difference between apply() and map() in Pandas.
'''
map() works on Series for element-wise operations, while apply() works on Series or DataFrames for row-wise or column-wise operations.
'''

# %%
# What are some advanced features of NumPy?
'''
NumPy provides advanced features like broadcasting, vectorization, linear algebra, and FFT for efficient numerical computing.
'''

# %%
# How does Pandas simplify time series analysis?
'''
In Pandas, time series analysis is simplified by built-in datetime support and time-based operations.
'''

# %%
# What is the role of a pivot table in Pandas?
'''
In Pandas, a pivot table is used to summarize and reorganize data by applying aggregation functions.
'''

# %%
# Why is NumPy’s array slicing faster than Python’s list slicing?
'''
In NumPy, array slicing is faster because it creates a view of the original data, not a copy, and operations are implemented in optimized C code.
'''

# %%
# What are some common use cases for Seaborn?
'''
Seaborn is mainly used for statistical visualization and exploratory data analysis in Python.
'''

# %%
# How do you create a 2D NumPy array and calculate the sum of each row?
import numpy as np
arr = np.array([[1, 2],[3, 4],[5, 6]])
row_sum = arr.sum(axis=1)
print(row_sum)
# Out:
# [ 3  7 11]

# %%
# Write a Pandas script to find the mean of a specific column in a DataFrame.
import pandas as pd
df = pd.DataFrame({
    "Marks": [70, 80, 90, 85]
})
mean_value = df["Marks"].mean()
print(mean_value)
# Out:
# 81.25

# %%
# Create a scatter plot using Matplotlib.
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Scatter plot
plt.scatter(x, y)
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Scatter Plot Example")
plt.show()

# %%
# How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap?
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.DataFrame({
    "A": [1, 2, 3, 4],
    "B": [2, 4, 6, 8],
    "C": [1, 3, 2, 5]
})
corr = df.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
# Generate a bar plot using Plotly.
import plotly.express as px
import pandas as pd
df = pd.DataFrame({
    "Category": ["A", "B", "C"],
    "Value": [10, 20, 15]
})
fig = px.bar(df, x="Category", y="Value")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create a DataFrame and add a new column based on an existing column.
import pandas as pd
df = pd.DataFrame({
    "Marks": [70, 80, 90]
})
df["Bonus_Marks"] = df["Marks"] + 5
print(df)
# Out:
#    Marks  Bonus_Marks
# 0     70           75
# 1     80           85
# 2     90           95

# %%
# Write a program to perform element-wise multiplication of two NumPy arrays.
import numpy as np
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
result = a * b
print(result)
# Out:
# [ 4 10 18]

# %%
# Create a line plot with multiple lines using Matplotlib.
import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y1 = [2, 4, 6, 8]
y2 = [1, 3, 5, 7]
plt.plot(x, y1, label="Line 1")
plt.plot(x, y2, label="Line 2")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.legend()
plt.title("Multiple Line Plot")
plt.show()

# %%
# Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold.
import pandas as pd
df = pd.DataFrame({
    "Score": [45, 72, 88, 60, 95]
})
threshold = 70
filtered_df = df[df["Score"] > threshold]
print(filtered_df)
# Out:
#    Score
# 1     72
# 2     88
# 4     95

# %%
# Create a histogram using Seaborn to visualize a distribution.
import seaborn as sns
import matplotlib.pyplot as plt
data = [10, 12, 15, 15, 18, 20, 22, 25]
sns.histplot(data, bins=5)
plt.show()

# %%
# Perform matrix multiplication using NumPy.
import numpy as np
A = np.array([[1, 2],
              [3, 4]])
B = np.array([[5, 6],
              [7, 8]])
result = A @ B
print(result)
# Out:
# [[19 22]
#  [43 50]]

# %%
# Use Pandas to load a CSV file and display its first 5 rows.
import pandas as pd
df = pd.read_csv("/content/sample_data/california_housing_test.csv")
print(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
# Create a 3D scatter plot using Plotly.
import plotly.express as px
import pandas as pd
df = pd.DataFrame({
    "x": [1, 2, 3, 4],
    "y": [4, 3, 2, 1],
    "z": [10, 20, 30, 40]
})
fig = px.scatter_3d(df, x="x", y="y", z="z")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
